# %%
#Defining it in a new way with one F2(z)
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import inv
mη = 0.547
mρ = 0.7755
mπ = 0.13957
m1 = 1.84
g1 = 1.41
g2 = -3.67
m2 = 2.99
h1 = 2.33
h2 = 5.28

def F2(z):
    return ((z**2)/(9 + (3*z) + (z**2)))

def ρ1(s,mηsq,mπsq):
    return ((2*(np.sqrt((s**2) + ((mηsq**2)**2) + ((mπsq**2)**2) - (2*s*(mηsq**2)) - (2*(mηsq**2)*(mπsq**2)) - (2*(mπsq**2)*s))/(2*np.sqrt(s)))/ (8*np.pi*np.sqrt(s))))

def ρ2(s,mρsq,mπsq):
    return ((2*(np.sqrt((s**2) + ((mρsq**2)**2) + ((mπsq**2)**2) - (2*s*(mρsq**2)) - (2*(mρsq**2)*(mπsq**2)) - (2*(mπsq**2)*s))/(2*np.sqrt(s)))/ (8*np.pi*np.sqrt(s))))

def ρ(s):
    return np.array([[ρ1(s,mη,mπ)*((F2(5*(p1)))**2),0], [0,ρ2(s,mρ,mπ)*((F2(5*(p2)))**2)]])



def K(s):
    return ((np.matrix ([[g1**2, g1*g2], [g2*h1, g2**2]])/ (m1**2 - s)) + (np.matrix([[h1**2, h1*h2], [h2*h1, h2**2]]) / (m2**2 - s)))
def M(s):
    a = ((ρ(s).dot(K(s))))
    return ((np.identity(2)-(1j*a)).dot(K(s)))

for s in np.linspace(1,5):
    p1 = np.sqrt ((s**2) + ((mη**2)**2) + ((mπ**2)**2) - (2*s*(mη**2)) - (2*(mη**2)*(mπ**2)) - (2*(mπ**2)*s))/ (2*np.sqrt(s))
    p2 = np.sqrt ((s**2) + ((mρ**2)**2) + ((mπ**2)**2) - (2*s*(mρ**2)) - (2*(mρ**2)*(mπ**2)) - (2*(mπ**2)*s))/ (2*np.sqrt(s))
    a = ρ(s)[0,0]*ρ(s)[1,1]
    M11 = F2((5*(p1))**2)*M(s)[0,0]*F2((5*(p1))**2)
    #print(p1)
    #print(p2)
    #print(F2((5*(p1))**2))
    #print(F2((5*(p2))**2))
    #print(ρ(s))
    #print(a)
    #print(K(s))
    #print(M(s))
    print(M11)
    #plt.plot(s,F2((5*(p1))**2),'g.')
    plt.plot(s,F2((5*(p2))**2),'r.')
    #plt.plot(s,a,'g.')
    #plt.plot(np.sqrt(s),M11.imag, 'g.')
# Out:
# (0.14152130031197113-0.00023802978442103484j)
# (0.1992487014378662-0.00045878423167451345j)
# (0.26231081466557427-0.000795944302797663j)
# (0.3290069299225511-0.0012791078297674746j)
# (0.398170716907188-0.0019417776518055791j)
# (0.469100468006703-0.0028235480372647954j)
# (0.5414667629338654-0.0039728606041124735j)
# (0.615230313714827-0.00545048363406205j)
# (0.6905805527759565-0.007334029108060469j)
# (0.7678961012925729-0.009724001506819442j)
# (0.8477252945898015-0.012752120727910465j)
# (0.9307849204703781-0.01659304286491347j)
# (1.0179766008081863-0.021481216442556152j)
# (1.1104222306571365-0.027735627957678765j)
# (1.2095225946825605-0.03579691687118726j)
# (1.3170471596437763-0.04628435594266634j)
# (1.4352690727190505-0.060085630935902294j)
# (1.567169468290478-0.07850252087360292j)
# (1.7167530249718774-0.10349539101888582j)
# (1.8895500209125553-0.13810989776206462j)
# (2.093445761236105-0.187256771334387j)
# (2.340115563204455-0.2592173094216324j)
# (2.6476517716832237-0.3687507885648683j)
# (3.045723300486896-0.5440643534975823j)
# (3.586661298084693-0.8442051946209671j)
# (4.372292509915041-1.4091015766884554j)
# (5.630716159838014-2.635744290354821j)
# (8.000248927661477-6.028211760387192j)
# (14.205710221085864-21.6395956902533j)
# (75.71551886226104-703.6943310337244j)
# (-21.166096916098347-63.326557679086555j)
# (-8.946395215258395-13.115498888960014j)
# (-5.513265971521811-5.817509244628332j)
# (-3.8865407472205993-3.40522835066246j)
# (-2.9315627113212472-2.3041206553925537j)
# (-2.299364628362395-1.7046435150456807j)
# (-1.8469440225446414-1.339860689843443j)
# (-1.5048336809418383-1.1002894017203664j)
# (-1.235207620907155-0.9340306077546169j)
# (-1.0156982240345935-0.8137934255237473j)
# (-0.8322233931990234-0.7240603810287742j)
# (-0.6754680873078076-0.6554529172890821j)
# (-0.5390180476952761-0.6020184637272302j)
# (-0.418306203997203-0.5598247871926821j)
# (-0.3099867603985846-0.52618684182442j)
# (-0.21154718884625537-0.49921986788385747j)
# (-0.12105884892999244-0.47757001952743594j)
# (-0.03701163124735119-0.4602460862651347j)
# (0.04179871704693241-0.44651108080113j)
# (0.11634925054841637-0.4358105114792855j)
